# %% [markdown]
# # 3 - Organizing Pandas: Summary

# %%
import pandas as pd
import numpy as np
import pandas_datareader as web
import datetime as dt
import scipy as sp
import math as m

start = dt.datetime(2012,1,1)
end = dt.datetime(2012,12,30)

msft = web.DataReader("WIKI/MSFT", "quandl", start, end)
aapl = web.DataReader("WIKI/AAPL", "quandl", start, end)

# %% [markdown]
# # Concatenation

# %% [markdown]
# ## Adding Dataframes Together

# %%
"""Problem"""

msftAV = msft[["AdjClose", "Volume"]] #by columns [[]], by index and column [][[]]
aaplAV = aapl[["AdjClose", "Volume"]]
(pd.concat([msftAV, aaplAV]))[:5]
# Out:
#              AdjClose      Volume
# Date
# 2012-12-28  23.257183  28239900.0
# 2012-12-27  23.616333  39394000.0
# 2012-12-26  23.528736  31631100.0
# 2012-12-24  23.703931  20842400.0
# 2012-12-21  24.045562  98776500.0

# %%
"""Solution"""
pd.concat([msftAV[:5], aaplAV[:5]], axis = 1,keys = ["MSFT", "AAPL"], join = "outer")
# Out:
#                  MSFT                   AAPL
#              AdjClose      Volume   AdjClose      Volume
# Date
# 2012-12-28  23.257183  28239900.0  66.081242  12652800.0
# 2012-12-27  23.616333  39394000.0  66.790671  16254300.0
# 2012-12-26  23.528736  31631100.0  66.523474  10801300.0
# 2012-12-24  23.703931  20842400.0  67.453053   6276900.0
# 2012-12-21  24.045562  98776500.0  67.344385  21295300.0

# %% [markdown]
# # Merge by Value

# %%
"""Reset index is needed so as to completely expose the columns as values"""
msftAR = msft[["AdjClose"]].reset_index()
msftVR = msft[["Volume"]].reset_index() 
(pd.merge(msftAR, msftAV, how = "outer"))[:5] #MERGE ==> NO []
# Out:
#         Date   AdjClose      Volume
# 0 2012-12-28  23.257183  28239900.0
# 1 2012-12-27  23.616333  39394000.0
# 2 2012-12-26  23.528736  31631100.0
# 3 2012-12-24  23.703931  20842400.0
# 4 2012-12-21  24.045562  98776500.0

# %% [markdown]
# # Pivoting

# %%
"""Transpose tables and insert values"""
#msft.insert(0, "Symbol", "MSFT")
#aapl.insert(0, "Symbol", "AAPL")
combined = pd.concat([msft, aapl]).sort_index()

s4p = combined.reset_index()
s4p[:5]
# Out:
#         Date Symbol      Open     High     Low    Close      Volume  \
# 0 2012-01-03   MSFT   26.5500   26.960   26.39   26.765  64731500.0
# 1 2012-01-03   AAPL  409.4000  412.500  409.00  411.230  10793600.0
# 2 2012-01-04   AAPL  410.0000  414.680  409.28  413.440   9286500.0
# 3 2012-01-04   MSFT   26.8199   27.470   26.78   27.400  80516100.0
# 4 2012-01-05   MSFT   27.3800   27.728   27.29   27.680  56081400.0
#
#    ExDividend  SplitRatio    AdjOpen    AdjHigh     AdjLow   AdjClose  \
# 0         0.0         1.0  22.609162  22.958305  22.472910  22.792249
# 1         0.0         1.0  52.613606  53.011999  52.562200  52.848787
# 2         0.0         1.0  52.690714  53.292160  52.598184  53.132802
# 3         0.0         1.0  22.839000  23.392605  22.805022  23.332995
# 4         0.0         1.0  23.315964  23.612310  23.239323  23.571435
#
#     AdjVolume
# 0  64731500.0
# 1  75555200.0
# 2  65005500.0
# 3  80516100.0
# 4  56081400.0

# %%
closes = s4p.pivot(index = "Date", columns = "Symbol", values = "AdjClose")
closes[:3]
# Out:
# Symbol           AAPL       MSFT
# Date
# 2012-01-03  52.848787  22.792249
# 2012-01-04  53.132802  23.332995
# 2012-01-05  53.722681  23.571435

# %% [markdown]
# # Stack/Unstack

# %%
"""Un-pivot"""
stack = closes.stack()
stack[:5]
# Out:
# Date        Symbol
# 2012-01-03  AAPL      52.848787
#             MSFT      22.792249
# 2012-01-04  AAPL      53.132802
#             MSFT      23.332995
# 2012-01-05  AAPL      53.722681
# dtype: float64

# %%
"""Re-pivot"""
(stack.unstack())[:3]
# Out:
# Symbol           AAPL       MSFT
# Date
# 2012-01-03  52.848787  22.792249
# 2012-01-04  53.132802  23.332995
# 2012-01-05  53.722681  23.571435

# %% [markdown]
# # Melting

# %%
"""unique-id variables"""
#Creates unique id variable Ffor everything --> melts all other data on date and symbol (like a tag)
melted = pd.melt(s4p, id_vars = ["Date", "Symbol"])

#Filter by tags
melted[(melted.Date == "2012-01-03") & (melted.Symbol == "MSFT")]
# Out:
#            Date Symbol    variable         value
# 0    2012-01-03   MSFT        Open  2.655000e+01
# 498  2012-01-03   MSFT        High  2.696000e+01
# 996  2012-01-03   MSFT         Low  2.639000e+01
# 1494 2012-01-03   MSFT       Close  2.676500e+01
# 1992 2012-01-03   MSFT      Volume  6.473150e+07
# 2490 2012-01-03   MSFT  ExDividend  0.000000e+00
# 2988 2012-01-03   MSFT  SplitRatio  1.000000e+00
# 3486 2012-01-03   MSFT     AdjOpen  2.260916e+01
# 3984 2012-01-03   MSFT     AdjHigh  2.295830e+01
# 4482 2012-01-03   MSFT      AdjLow  2.247291e+01
# 4980 2012-01-03   MSFT    AdjClose  2.279225e+01
# 5478 2012-01-03   MSFT   AdjVolume  6.473150e+07

# %% [markdown]
# # Split-apply-combine

# %%
"""1) Split into groups"""
#Reset the index on the pivot df and additional date columns for grouping
s4g = combined[["Symbol", "AdjClose"]].reset_index()
s4g.insert(1, "Year", pd.DatetimeIndex(s4g["Date"]).year) #Get year from date as index
s4g.insert(2, "Month", pd.DatetimeIndex(s4g["Date"]).month) #Get month from date as index

#To use the groupby method:
def print_groups(obj):
    for name, group in obj:
        print (name)
        print (group.head())
        
#Single grouping
grouped = s4g.groupby("Symbol") #in this way you can grouped.getgroup("symbol you want to find")
#Multi-level grouping
mcg = s4g.groupby(["Symbol", "Year", "Month"])
#Hierarchical grouping: Set_index to give each group index a hierarchy (level: 0, 1, 2 ...)
mi = s4g.set_index(["Symbol", "Year", "Month"]) #groupby(level = 0)
#Multi-level Hierarchical grouping:
mih = mi.groupby(level = ["Symbol", "Year", "Month"])
print_groups(mih)
# Out:
# ('AAPL', 2012, 1)
#                         Date   AdjClose
# Symbol Year Month
# AAPL   2012 1     2012-01-03  52.848787
#             1     2012-01-04  53.132802
#             1     2012-01-05  53.722681
#             1     2012-01-06  54.284287
#             1     2012-01-09  54.198183
# ('AAPL', 2012, 2)
#                         Date   AdjClose
# Symbol Year Month
# AAPL   2012 2     2012-02-01  58.626773
#             2     2012-02-02  58.489263
#             2     2012-02-03  59.075287
#             2     2012-02-06  59.626612
#             2     2012-02-07  60.251189
# ('AAPL', 2012, 3)
#                         Date   AdjClose
# Symbol Year Month
# AAPL   2012 3     2012-03-01  69.971984
#             3     2012-03-02  70.063229
#             3     2012-03-05  68.518491
#             3     2012-03-06  68.145801
#             3     2012-03-07  68.201062
# ('AAPL', 2012, 4)
#                         Date   AdjClose
# Symbol Year Month
# AAPL   2012 4     2012-04-02  79.502577
#             4     2012-04-03  80.876391
#             4     2012-04-04  80.232536
#             4     2012-04-05  81.436712
#             4     2012-04-09  81.764423
# ('AAPL', 2012, 5)
#                         Date   AdjClose
# Symbol Year Month
# AAPL   2012 5     2012-05-01  74.811819
#             5     2012-05-02  75.306597
#             5     2012-05-03  74.771979
#             5     2012-05-04  72.642503
#             5     2012-05-07  73.186117
# ('AAPL', 2012, 6)
#                         Date   AdjClose
# Symbol Year Month
# AAPL   2012 6     2012-06-01  72.095034
#             6     2012-06-04  72.519130
#             6     2012-06-05  72.331500
#             6     2012-06-06  73.440575
#             6     2012-06-07  73.473988
# ('AAPL', 2012, 7)
#                         Date   AdjClose
# Symbol Year Month
# AAPL   2012 7     2012-07-02  76.147078
#             7     2012-07-03  77.032539
#             7     2012-07-05  78.385791
#             7     2012-07-06  77.864025
#             7     2012-07-09  78.893421
# ('AAPL', 2012, 8)
#                         Date   AdjClose
# Symbol Year Month
# AAPL   2012 8     2012-08-01  77.983543
#             8     2012-08-02  78.109486
#             8     2012-08-03  79.126031
#             8     2012-08-06  80.006352
#             8     2012-08-07  79.796103
# ('AAPL', 2012, 9)
#                         Date   AdjClose
# Symbol Year Month
# AAPL   2012 9     2012-09-04  87.113373
#             9     2012-09-05  86.501616
#             9     2012-09-06  87.281154
#             9     2012-09-07  87.819345
#             9     2012-09-10  85.534938
# ('AAPL', 2012, 10)
#                         Date   AdjClose
# Symbol Year Month
# AAPL   2012 10    2012-10-01  85.102578
#             10    2012-10-02  85.350378
#             10    2012-10-03  86.659073
#             10    2012-10-04  86.058932
#             10    2012-10-05  84.224952
# ('AAPL', 2012, 11)
#                         Date   AdjClose
# Symbol Year Month
# AAPL   2012 11    2012-11-01  76.990982
#             11    2012-11-02  74.443299
#             11    2012-11-05  75.452710
#             11    2012-11-06  75.224063
#             11    2012-11-07  72.359184
# ('AAPL', 2012, 12)
#                         Date   AdjClose
# Symbol Year Month
# AAPL   2012 12    2012-12-03  76.014490
#             12    2012-12-04  74.673049
#             12    2012-12-05  69.868169
#             12    2012-12-06  70.964212
#             12    2012-12-07  69.149468
# ('MSFT', 2012, 1)
#                         Date   AdjClose
# Symbol Year Month
# MSFT   2012 1     2012-01-03  22.792249
#             1     2012-01-04  23.332995
#             1     2012-01-05  23.571435
#             1     2012-01-06  23.933352
#             1     2012-01-09  23.622529
# ('MSFT', 2012, 2)
#                         Date   AdjClose
# Symbol Year Month
# MSFT   2012 2     2012-02-01  25.453403
#             2     2012-02-02  25.504497
#             2     2012-02-03  25.751452
#             2     2012-02-06  25.717389
#             2     2012-02-07  25.845124
# ('MSFT', 2012, 3)
#                         Date   AdjClose
# Symbol Year Month
# MSFT   2012 3     2012-03-01  27.678968
#             3     2012-03-02  27.494670
#             3     2012-03-05  27.258940
#             3     2012-03-06  27.048927
#             3     2012-03-07  27.293228
# ('MSFT', 2012, 4)
#                         Date   AdjClose
# Symbol Year Month
# MSFT   2012 4     2012-04-02  27.678968
#             4     2012-04-03  27.378948
#             4     2012-04-04  26.753193
#             4     2012-04-05  27.018925
#             4     2012-04-09  26.658901
# ('MSFT', 2012, 5)
